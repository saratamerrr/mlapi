# %%
pip install -r "D:\Masters\Big Data\mlapi\app\requirements.txt"
# Out:
# Collecting Flask (from -r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1))
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: pandas in c:\python312\lib\site-packages (from -r D:\Masters\Big Data\mlapi\app\requirements.txt (line 2)) (2.2.2)
# Collecting scikit-learn (from -r D:\Masters\Big Data\mlapi\app\requirements.txt (line 3))
#   Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting joblib (from -r D:\Masters\Big Data\mlapi\app\requirements.txt (line 4))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting Werkzeug>=3.0.0 (from Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1))
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\python312\lib\site-packages (from Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1)) (3.1.4)
# Collecting itsdangerous>=2.1.2 (from Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1))
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1.3 in c:\python312\lib\site-packages (from Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\python312\lib\site-packages (from Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1)) (1.8.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\python312\lib\site-packages (from pandas->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python312\lib\site-packages (from pandas->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python312\lib\site-packages (from pandas->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 2)) (2024.1)
# Collecting scipy>=1.6.0 (from scikit-learn->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 3))
#   Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB 1.6 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 3))
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from click>=8.1.3->Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\python312\lib\site-packages (from Jinja2>=3.1.2->Flask->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r D:\Masters\Big Data\mlapi\app\requirements.txt (line 2)) (1.16.0)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.7 kB ? eta -:--:--
#    ---------------------------------------- 101.7/101.7 kB ? eta 0:00:00
# Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.6 MB 6.3 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/10.6 MB 8.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/10.6 MB 10.6 MB/s eta 0:00:01
#    ------- -------------------------------- 1.9/10.6 MB 10.9 MB/s eta 0:00:01
#    --------- ------------------------------ 2.4/10.6 MB 11.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.9/10.6 MB 11.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.6 MB 11.1 MB/s eta 0:00:01
#    --------------- ------------------------ 4.0/10.6 MB 11.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.5/10.6 MB 11.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.1/10.6 MB 11.3 MB/s eta 0:00:01
#    --------------------- ------------------ 5.6/10.6 MB 11.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.1/10.6 MB 11.1 MB/s eta 0:00:01
#    ------------------------ --------------- 6.5/10.6 MB 11.0 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.6 MB 11.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.5/10.6 MB 11.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.6 MB 10.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.7/10.6 MB 10.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.3/10.6 MB 10.0 MB/s eta 0:00:01
#    --------------------------------- ------ 8.8/10.6 MB 10.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.6 MB 10.1 MB/s eta 0:00:01
#    ------------------------------------- -- 9.9/10.6 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  10.4/10.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 9.9 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ---------------------------------------- 301.8/301.8 kB 9.4 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl (45.9 MB)
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/45.9 MB 9.4 MB/s eta 0:00:05
#     --------------------------------------- 1.0/45.9 MB 10.1 MB/s eta 0:00:05
#    - -------------------------------------- 1.4/45.9 MB 11.1 MB/s eta 0:00:04
#    - -------------------------------------- 1.9/45.9 MB 10.9 MB/s eta 0:00:05
#    -- ------------------------------------- 2.4/45.9 MB 11.0 MB/s eta 0:00:04
#    -- ------------------------------------- 3.0/45.9 MB 11.2 MB/s eta 0:00:04
#    --- ------------------------------------ 3.5/45.9 MB 11.1 MB/s eta 0:00:04
#    --- ------------------------------------ 3.7/45.9 MB 10.3 MB/s eta 0:00:05
#    --- ------------------------------------ 4.2/45.9 MB 10.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.7/45.9 MB 10.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.2/45.9 MB 10.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.8/45.9 MB 10.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.3/45.9 MB 10.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.8/45.9 MB 10.6 MB/s eta 0:00:04
#    ------ --------------------------------- 7.1/45.9 MB 10.5 MB/s eta 0:00:04
#    ------ --------------------------------- 7.3/45.9 MB 10.0 MB/s eta 0:00:04
#    ------ --------------------------------- 8.0/45.9 MB 9.8 MB/s eta 0:00:04
#    ------- -------------------------------- 8.7/45.9 MB 9.9 MB/s eta 0:00:04
#    ------- -------------------------------- 9.1/45.9 MB 9.8 MB/s eta 0:00:04
#    -------- ------------------------------- 9.6/45.9 MB 9.9 MB/s eta 0:00:04
#    -------- ------------------------------- 10.2/45.9 MB 10.0 MB/s eta 0:00:04
#    --------- ------------------------------ 10.7/45.9 MB 10.1 MB/s eta 0:00:04
#    --------- ------------------------------ 11.2/45.9 MB 10.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 11.7/45.9 MB 10.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 12.3/45.9 MB 10.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 12.8/45.9 MB 10.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.3/45.9 MB 10.1 MB/s eta 0:00:04
#    ------------ --------------------------- 13.8/45.9 MB 10.2 MB/s eta 0:00:04
#    ------------ --------------------------- 14.2/45.9 MB 10.2 MB/s eta 0:00:04
#    ------------ --------------------------- 14.8/45.9 MB 10.2 MB/s eta 0:00:04
#    ------------- -------------------------- 15.3/45.9 MB 10.6 MB/s eta 0:00:03
#    ------------- -------------------------- 15.9/45.9 MB 10.4 MB/s eta 0:00:03
#    -------------- ------------------------- 16.4/45.9 MB 10.4 MB/s eta 0:00:03
#    -------------- ------------------------- 16.7/45.9 MB 10.2 MB/s eta 0:00:03
#    --------------- ------------------------ 17.2/45.9 MB 10.2 MB/s eta 0:00:03
#    --------------- ------------------------ 17.6/45.9 MB 11.3 MB/s eta 0:00:03
#    --------------- ------------------------ 18.3/45.9 MB 11.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.8/45.9 MB 10.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.0/45.9 MB 10.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 19.4/45.9 MB 10.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.0/45.9 MB 10.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 20.4/45.9 MB 10.6 MB/s eta 0:00:03
#    ------------------ --------------------- 21.0/45.9 MB 10.6 MB/s eta 0:00:03
#    ------------------ --------------------- 21.3/45.9 MB 10.4 MB/s eta 0:00:03
#    ------------------ --------------------- 21.6/45.9 MB 10.2 MB/s eta 0:00:03
#    ------------------- -------------------- 22.1/45.9 MB 10.2 MB/s eta 0:00:03
#    ------------------- -------------------- 22.7/45.9 MB 10.2 MB/s eta 0:00:03
#    -------------------- ------------------- 23.2/45.9 MB 10.2 MB/s eta 0:00:03
#    -------------------- ------------------- 23.7/45.9 MB 10.1 MB/s eta 0:00:03
#    -------------------- ------------------- 24.0/45.9 MB 10.1 MB/s eta 0:00:03
#    --------------------- ------------------ 24.6/45.9 MB 10.1 MB/s eta 0:00:03
#    --------------------- ------------------ 25.0/45.9 MB 9.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.5/45.9 MB 9.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 26.0/45.9 MB 9.9 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.5/45.9 MB 9.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.0/45.9 MB 10.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 27.5/45.9 MB 10.1 MB/s eta 0:00:02
#    ------------------------ --------------- 28.0/45.9 MB 10.1 MB/s eta 0:00:02
#    ------------------------ --------------- 28.5/45.9 MB 9.9 MB/s eta 0:00:02
#    ------------------------- -------------- 29.1/45.9 MB 9.9 MB/s eta 0:00:02
#    ------------------------- -------------- 29.3/45.9 MB 10.1 MB/s eta 0:00:02
#    ------------------------- -------------- 29.8/45.9 MB 10.1 MB/s eta 0:00:02
#    -------------------------- ------------- 30.4/45.9 MB 10.1 MB/s eta 0:00:02
#    -------------------------- ------------- 30.9/45.9 MB 10.2 MB/s eta 0:00:02
#    --------------------------- ------------ 31.5/45.9 MB 10.4 MB/s eta 0:00:02
#    --------------------------- ------------ 31.8/45.9 MB 10.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.4/45.9 MB 10.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.9/45.9 MB 10.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.4/45.9 MB 10.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 34.0/45.9 MB 10.7 MB/s eta 0:00:02
#    ------------------------------ --------- 34.5/45.9 MB 10.9 MB/s eta 0:00:02
#    ------------------------------ --------- 35.1/45.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 35.6/45.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 36.2/45.9 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 36.7/45.9 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 37.1/45.9 MB 10.9 MB/s eta 0:00:01
#    -------------------------------- ------- 37.7/45.9 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 38.3/45.9 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 38.8/45.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.4/45.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.9/45.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.4/45.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.9/45.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 41.4/45.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 41.9/45.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------------ --- 42.4/45.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 43.0/45.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 43.3/45.9 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 43.9/45.9 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.4/45.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  44.9/45.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  45.0/45.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  45.4/45.9 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  45.8/45.9 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------- 45.9/45.9 MB 9.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.3 kB ? eta -:--:--
#    --------------------------------------- 227.3/227.3 kB 14.5 MB/s eta 0:00:00
# Installing collected packages: Werkzeug, threadpoolctl, scipy, joblib, itsdangerous, scikit-learn, Flask
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'c:\\Python312\\Scripts\\flask.exe' -> 'c:\\Python312\\Scripts\\flask.exe.deleteme'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn import metrics
import joblib

# %%
data = pd.read_csv('iris.csv')

# %%
y = data['species']
X = data.drop(columns=['species'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)

# %%
column_names = list(X_train.columns)

# %%
imp = SimpleImputer(strategy='median')

# %%
ct = ColumnTransformer([('imputer', imp, column_names)])

# %%
clf = RandomForestClassifier(random_state=23)

# %%
pipe = Pipeline([
    ('preprocessor', ct),
    ('classifier', clf)]
)

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('imputer',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['sepal_length',
#                                                    'sepal_width',
#                                                    'petal_length',
#                                                    'petal_width'])])),
#                 ('classifier', RandomForestClassifier(random_state=23))])

# %%
y_pred = pipe.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       0.93      1.00      0.97        14
#  Iris-virginica       1.00      0.92      0.96        13
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.97      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
joblib.dump(pipe, '../app/iris.mdl')
# Out:
# ['../app/iris.mdl']
